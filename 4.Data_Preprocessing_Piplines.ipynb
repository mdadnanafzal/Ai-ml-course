# %% [markdown]
# ### Prediction of MPG

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.shape
# Out:
# (398, 9)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
#     X - Features on the basis of which target can estimated
#     y - target / label which we want to predict using ML model

# %%
mpg.head().drop([1, 3, 4])
# axis=0, delete rows by default using row indexes
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 2          70    usa         plymouth satellite

# %%
mpg.head().drop(["mpg", "name", "origin"], axis=1)
# axis=1, delete columns using column indexes
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70

# %%
mpg.head().drop("mpg", axis=1)
# features selection
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
mpg.drop(["mpg", "cylinders", "model_year", "origin", "name"], axis=1).head()
# Out:
#    displacement  horsepower  weight  acceleration
# 0         307.0       130.0    3504          12.0
# 1         350.0       165.0    3693          11.5
# 2         318.0       150.0    3436          11.0
# 3         304.0       150.0    3433          12.0
# 4         302.0       140.0    3449          10.5

# %%
X = mpg.drop("mpg", axis=1)
y = mpg["mpg"]

# %%
X.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %% [markdown]
# #### Hypothesis or Objective
#
#     mileage of a vechile can be predicted using it's features like no of cylinders, horse power,
#     displacement, weight, acceleration, model_year, origin and manufractuer name
#
# #### Sampling
#
#     picking training and testing data
#
# #### EDA
#
#     feature selection
#     hyothesis testing
#
# #### Data Modeling
#
#     preparing data for machine learning models
#
#         1. Fix Missing Values
#         2. Fix Outliers
#         3. Convert Categorical / Text to a numerical form
#         4. Scaling
#         5. Feature Engineering
#                     1) Feature Selection -> drop irrelevent features and select important features
#                     2) Feature Embedding -> we can combine multiplie feature using a logical relation
#                                             to form a new feature
#
# #### Training ML model
#
#         select and train a machine learning model
#
# #### Hyper-parameter Tuning
#
#         improving performance of ML model by selecting best value for hyper parameters
#
# #### Deployment ML Model
#
#         integrate a machine learning model with real time application and make it live

# %% [markdown]
# #### Sampling
#
#     choosing test and train set from population of given data in such way that train and test data is distinct

# %%
X.shape[0]
# Out:
# 398

# %%
X.shape[0] * 0.1
# Out:
# 39.800000000000004

# %%
from sklearn.model_selection import train_test_split
# random sampling

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=45)

# %%
X.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
X_train.head()
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 178          4         120.0        88.0    2957          17.0          75
# 299          4         141.0        71.0    3190          24.8          79
# 360          6         145.0        76.0    3160          19.6          81
# 313          4         151.0        90.0    2678          16.5          80
# 52           4          88.0        76.0    2065          14.5          71
#
#      origin                name
# 178  europe         peugeot 504
# 299  europe         peugeot 504
# 360  europe        volvo diesel
# 313     usa  chevrolet citation
# 52   europe           fiat 124b

# %%
num_features = ["displacement", "horsepower", "weight", "acceleration"]

# %%
X_train[num_features].corrwith(y_train)
# Out:
# displacement   -0.808184
# horsepower     -0.775395
# weight         -0.833607
# acceleration    0.417611
# dtype: float64

# %%
for column in num_features:
    r = np.corrcoef(X_train[column], y_train)[0, 1]
    plt.plot(X_train[column], y_train, "ob", mfc="white",
             alpha=0.5, label=f"r = {r:0.2f}")
    plt.xlabel(column)
    plt.ylabel("mpg")
    plt.title(f"{column} vs MPG")
    plt.legend()
    plt.show()

# %% [markdown]
# ### analysis of categorical features

# %%
df = X_train.copy()
df["mpg"] = y_train

# %%
df.head()
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 178          4         120.0        88.0    2957          17.0          75
# 299          4         141.0        71.0    3190          24.8          79
# 360          6         145.0        76.0    3160          19.6          81
# 313          4         151.0        90.0    2678          16.5          80
# 52           4          88.0        76.0    2065          14.5          71
#
#      origin                name   mpg
# 178  europe         peugeot 504  23.0
# 299  europe         peugeot 504  27.2
# 360  europe        volvo diesel  30.7
# 313     usa  chevrolet citation  28.0
# 52   europe           fiat 124b  30.0

# %%
df.groupby("cylinders")["mpg"].describe().sort_values("mean", ascending=False)
# Out:
#            count       mean        std   min     25%    50%     75%   max
# cylinders
# 4          183.0  29.507104   5.743980  19.0  25.000  29.00  33.250  46.6
# 5            2.0  28.350000  11.384419  20.3  24.325  28.35  32.375  36.4
# 3            4.0  20.550000   2.564501  18.0  18.750  20.25  22.050  23.7
# 6           79.0  20.013924   3.861969  15.0  18.000  19.00  21.000  38.0
# 8           90.0  14.694444   2.441604   9.0  13.000  14.00  16.000  23.9

# %%
sns.scatterplot(x="horsepower", y="mpg", hue="cylinders", data=df,
               palette="coolwarm")
plt.show()

# %%
df.groupby("model_year")["mpg"].describe()\
.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_78185_row0_col0, #T_78185_row0_col3, #T_78185_row0_col5, #T_78185_row0_col7, #T_78185_row2_col0, #T_78185_row2_col4, #T_78185_row3_col1, #T_78185_row3_col2, #T_78185_row3_col4, #T_78185_row3_col5, #T_78185_row3_col6, #T_78185_row4_col0, #T_78185_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_78185_row0_col1, #T_78185_row2_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_78185_row0_col2, #T_78185_row6_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_78185_row0_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_78185_row0_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_78185_row1_col0, #T_78185_row5_col0, #T_78185_row9_col0, #T_78185_row11_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_78185_row1_col1, #T_78185_row6_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_78185_row1_col2, #T_78185_row10_col3 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_78185_row1_col3, #T_78185_row5_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_78185_row1_col4, #T_78185_row5_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_78185_row1_col5, #T_78185_row2_col5, #T_78185_row4_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_78185_row1_col6, #T_78185_row7_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_78185_row1_col7, #T_78185_row2_col2, #T_78185_row7_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_78185_row2_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_78185_row2_col3, #T_78185_row3_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_78185_row2_col6, #T_78185_row5_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_78185_row3_col0, #T_78185_row8_col2, #T_78185_row10_col1, #T_78185_row10_col4, #T_78185_row10_col5, #T_78185_row10_col6, #T_78185_row10_col7, #T_78185_row12_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_78185_row3_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_78185_row4_col1 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_78185_row4_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_78185_row4_col3, #T_78185_row5_col3, #T_78185_row6_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_78185_row4_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_78185_row4_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_78185_row4_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_78185_row5_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_78185_row5_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_78185_row5_col7, #T_78185_row6_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_78185_row6_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_78185_row6_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_78185_row6_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_78185_row6_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_78185_row7_col2 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_78185_row7_col3, #T_78185_row8_col1, #T_78185_row9_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_78185_row7_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_78185_row7_col6 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_78185_row7_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_78185_row8_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_78185_row8_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_78185_row8_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_78185_row8_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_78185_row8_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_78185_row8_col7 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_78185_row9_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_78185_row9_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_78185_row9_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_78185_row9_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_78185_row9_col6 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_78185_row9_col7 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_78185_row10_col0, #T_78185_row12_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_78185_row10_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_78185_row11_col1 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_78185_row11_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_78185_row11_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_78185_row11_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_78185_row11_col5 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_78185_row11_col6 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_78185_row11_col7 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_78185_row12_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_78185_row12_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_78185_row12_col4 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_78185_row12_col5 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_78185_row12_col6 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_78185_row12_col7 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_78185">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78185_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_78185_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_78185_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_78185_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_78185_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_78185_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_78185_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_78185_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78185_level0_row0" class="row_heading level0 row0" >70</th>
#       <td id="T_78185_row0_col0" class="data row0 col0" >25.000000</td>
#       <td id="T_78185_row0_col1" class="data row0 col1" >17.840000</td>
#       <td id="T_78185_row0_col2" class="data row0 col2" >5.312564</td>
#       <td id="T_78185_row0_col3" class="data row0 col3" >9.000000</td>
#       <td id="T_78185_row0_col4" class="data row0 col4" >14.000000</td>
#       <td id="T_78185_row0_col5" class="data row0 col5" >16.000000</td>
#       <td id="T_78185_row0_col6" class="data row0 col6" >22.000000</td>
#       <td id="T_78185_row0_col7" class="data row0 col7" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_78185_level0_row1" class="row_heading level0 row1" >71</th>
#       <td id="T_78185_row1_col0" class="data row1 col0" >26.000000</td>
#       <td id="T_78185_row1_col1" class="data row1 col1" >21.269231</td>
#       <td id="T_78185_row1_col2" class="data row1 col2" >6.557790</td>
#       <td id="T_78185_row1_col3" class="data row1 col3" >12.000000</td>
#       <td id="T_78185_row1_col4" class="data row1 col4" >16.250000</td>
#       <td id="T_78185_row1_col5" class="data row1 col5" >19.000000</td>
#       <td id="T_78185_row1_col6" class="data row1 col6" >26.750000</td>
#       <td id="T_78185_row1_col7" class="data row1 col7" >35.000000</td>
#     </tr>
#     <tr>
#       <th id="T_78185_level0_row2" class="row_heading level0 row2" >72</th>
#       <td id="T_78185_row2_col0" class="data row2 col0" >25.000000</td>
#       <td id="T_78185_row2_col1" class="data row2 col1" >18.800000</td>

# %%
sns.scatterplot(x="horsepower", y="mpg", hue="model_year", data=df,
               palette="coolwarm")
plt.show()

# %%
df.groupby("origin")["mpg"].describe()\
.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_914f7_row0_col0, #T_914f7_row1_col2, #T_914f7_row2_col1, #T_914f7_row2_col3, #T_914f7_row2_col4, #T_914f7_row2_col5, #T_914f7_row2_col6, #T_914f7_row2_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_914f7_row0_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_914f7_row0_col2, #T_914f7_row1_col1, #T_914f7_row1_col3, #T_914f7_row1_col4, #T_914f7_row1_col5, #T_914f7_row1_col6, #T_914f7_row1_col7, #T_914f7_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_914f7_row0_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_914f7_row0_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_914f7_row0_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_914f7_row0_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_914f7_row0_col7 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_914f7_row1_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_914f7_row2_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_914f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_914f7_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_914f7_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_914f7_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_914f7_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_914f7_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_914f7_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_914f7_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_914f7_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >origin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_914f7_level0_row0" class="row_heading level0 row0" >europe</th>
#       <td id="T_914f7_row0_col0" class="data row0 col0" >60.000000</td>
#       <td id="T_914f7_row0_col1" class="data row0 col1" >28.111667</td>
#       <td id="T_914f7_row0_col2" class="data row0 col2" >7.065315</td>
#       <td id="T_914f7_row0_col3" class="data row0 col3" >16.200000</td>
#       <td id="T_914f7_row0_col4" class="data row0 col4" >23.000000</td>
#       <td id="T_914f7_row0_col5" class="data row0 col5" >27.000000</td>
#       <td id="T_914f7_row0_col6" class="data row0 col6" >31.125000</td>
#       <td id="T_914f7_row0_col7" class="data row0 col7" >44.300000</td>
#     </tr>
#     <tr>
#       <th id="T_914f7_level0_row1" class="row_heading level0 row1" >japan</th>
#       <td id="T_914f7_row1_col0" class="data row1 col0" >75.000000</td>
#       <td id="T_914f7_row1_col1" class="data row1 col1" >30.260000</td>
#       <td id="T_914f7_row1_col2" class="data row1 col2" >6.168096</td>
#       <td id="T_914f7_row1_col3" class="data row1 col3" >18.000000</td>
#       <td id="T_914f7_row1_col4" class="data row1 col4" >25.200000</td>
#       <td id="T_914f7_row1_col5" class="data row1 col5" >31.300000</td>
#       <td id="T_914f7_row1_col6" class="data row1 col6" >33.950000</td>
#       <td id="T_914f7_row1_col7" class="data row1 col7" >46.600000</td>
#     </tr>
#     <tr>
#       <th id="T_914f7_level0_row2" class="row_heading level0 row2" >usa</th>
#       <td id="T_914f7_row2_col0" class="data row2 col0" >223.000000</td>
#       <td id="T_914f7_row2_col1" class="data row2 col1" >20.117040</td>
#       <td id="T_914f7_row2_col2" class="data row2 col2" >6.526431</td>
#       <td id="T_914f7_row2_col3" class="data row2 col3" >9.000000</td>
#       <td id="T_914f7_row2_col4" class="data row2 col4" >15.000000</td>
#       <td id="T_914f7_row2_col5" class="data row2 col5" >18.500000</td>
#       <td id="T_914f7_row2_col6" class="data row2 col6" >24.400000</td>
#       <td id="T_914f7_row2_col7" class="data row2 col7" >39.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.scatterplot(x="horsepower", y="mpg", hue="origin", data=df,
               palette="coolwarm")
plt.show()

# %%
X_train[num_features].corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_ea370_row0_col0, #T_ea370_row1_col1, #T_ea370_row2_col2, #T_ea370_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ea370_row0_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_ea370_row0_col2 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_ea370_row0_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ea370_row1_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_ea370_row1_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_ea370_row1_col3, #T_ea370_row3_col0, #T_ea370_row3_col1, #T_ea370_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ea370_row2_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_ea370_row2_col1 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_ea370_row2_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ea370">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea370_level0_col0" class="col_heading level0 col0" >displacement</th>
#       <th id="T_ea370_level0_col1" class="col_heading level0 col1" >horsepower</th>
#       <th id="T_ea370_level0_col2" class="col_heading level0 col2" >weight</th>
#       <th id="T_ea370_level0_col3" class="col_heading level0 col3" >acceleration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea370_level0_row0" class="row_heading level0 row0" >displacement</th>
#       <td id="T_ea370_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ea370_row0_col1" class="data row0 col1" >0.898815</td>
#       <td id="T_ea370_row0_col2" class="data row0 col2" >0.932052</td>
#       <td id="T_ea370_row0_col3" class="data row0 col3" >-0.549561</td>
#     </tr>
#     <tr>
#       <th id="T_ea370_level0_row1" class="row_heading level0 row1" >horsepower</th>
#       <td id="T_ea370_row1_col0" class="data row1 col0" >0.898815</td>
#       <td id="T_ea370_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ea370_row1_col2" class="data row1 col2" >0.863924</td>
#       <td id="T_ea370_row1_col3" class="data row1 col3" >-0.690146</td>
#     </tr>
#     <tr>
#       <th id="T_ea370_level0_row2" class="row_heading level0 row2" >weight</th>
#       <td id="T_ea370_row2_col0" class="data row2 col0" >0.932052</td>
#       <td id="T_ea370_row2_col1" class="data row2 col1" >0.863924</td>
#       <td id="T_ea370_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ea370_row2_col3" class="data row2 col3" >-0.419567</td>
#     </tr>
#     <tr>
#       <th id="T_ea370_level0_row3" class="row_heading level0 row3" >acceleration</th>
#       <td id="T_ea370_row3_col0" class="data row3 col0" >-0.549561</td>
#       <td id="T_ea370_row3_col1" class="data row3 col1" >-0.690146</td>
#       <td id="T_ea370_row3_col2" class="data row3 col2" >-0.419567</td>
#       <td id="T_ea370_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df["dhw"] = (df["displacement"]+df["horsepower"])+df["weight"]

# %%
df.corr()
# Out:
# C:\Users\mdadn\AppData\Local\Temp\ipykernel_24548\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               cylinders  displacement  horsepower    weight  acceleration  \
# cylinders      1.000000      0.948899    0.842235  0.897663     -0.504459
# displacement   0.948899      1.000000    0.898815  0.932052     -0.549561
# horsepower     0.842235      0.898815    1.000000  0.863924     -0.690146
# weight         0.897663      0.932052    0.863924  1.000000     -0.419567
# acceleration  -0.504459     -0.549561   -0.690146 -0.419567      1.000000
# model_year    -0.370957     -0.389419   -0.424870 -0.314186      0.285543
# mpg           -0.782206     -0.808184   -0.775395 -0.833607      0.417611
# dhw            0.912510      0.948584    0.882618  0.998677     -0.448157
#
#               model_year       mpg       dhw
# cylinders      -0.370957 -0.782206  0.912510
# displacement   -0.389419 -0.808184  0.948584
# horsepower     -0.424870 -0.775395  0.882618
# weight         -0.314186 -0.833607  0.998677
# acceleration    0.285543  0.417611 -0.448157
# model_year      1.000000  0.580747 -0.332643
# mpg             0.580747  1.000000 -0.838537
# dhw            -0.332643 -0.838537  1.000000

# %%
df["name"].nunique() # 398 -> 281
# Out:
# 281

# %%
print(*df["name"].unique(), sep="\n")
# Out:
# peugeot 504
# volvo diesel
# chevrolet citation
# fiat 124b
# oldsmobile cutlass supreme
# ford granada gl
# pontiac lemans v6
# oldsmobile delta 88 royale
# renault lecar deluxe
# pontiac catalina
# chevrolet vega
# buick century limited
# plymouth horizon
# saab 99le
# datsun f-10 hatchback
# amc spirit dl
# amc ambassador brougham
# ford ranger
# pontiac astro
# chevrolet chevette
# ford fairmont futura
# amc rebel sst
# amc hornet
# chevrolet malibu classic (sw)
# amc gremlin
# chevrolet nova
# ford mustang ii
# mazda rx-4
# amc hornet sportabout (sw)
# amc concord
# datsun 710
# plymouth reliant
# plymouth volare premier v8
# datsun 510 hatchback
# chevrolet chevelle concours (sw)
# renault 12 (sw)
# chrysler lebaron medallion
# datsun b-210
# chevrolet chevelle malibu classic
# buick skylark
# dodge diplomat
# audi 100ls
# honda civic
# ford pinto
# chevrolet camaro
# chrysler lebaron town @ country (sw)
# plymouth duster
# ford fairmont 4
# ford escort 2h
# ford gran torino (sw)
# honda civic 1500 gl
# ford fairmont
# maxda glc deluxe
# chevrolet vega (sw)
# oldsmobile cutlass salon brougham
# chevrolet caprice classic
# opel manta
# pontiac firebird
# audi 5000s (diesel)
# chevrolet chevelle malibu
# honda civic (auto)
# triumph tr7 coupe
# chevrolet vega 2300
# fiat strada custom
# saab 99e
# buick estate wagon (sw)
# buick skylark limited
# mazda glc
# toyota corona
# volvo 244dl
# datsun b210
# chevy s-10
# honda accord cvcc
# dodge rampage
# plymouth sapporo
# ford pinto (sw)
# toyota carina
# dodge colt hatchback custom
# datsun 810 maxima
# dodge dart custom
# toyota tercel
# ford ltd
# dodge aspen
# buick skylark 320
# chevrolet concours
# honda accord
# honda accord lx
# amc concord d/l
# maxda rx3
# dodge monaco brougham
# ford mustang cobra
# toyota corolla
# dodge colt (sw)
# toyota mark ii
# datsun 280-zx
# ford maverick
# amc pacer d/l
# ford f108
# peugeot 604sl
# pontiac phoenix
# volkswagen dasher
# toyota celica gt
# mercury zephyr
# mercedes-benz 240d
# datsun pl510
# chevrolet monte carlo s
# ford ltd landau
# buick century luxus (sw)
# plymouth horizon 4
# plymouth arrow gs
# ford escort 4w
# subaru
# pontiac safari (sw)
# mercury lynx l
# dodge coronet custom (sw)
# mazda 626
# mercury marquis
# volvo 264gl
# pontiac grand prix
# plymouth valiant
# volkswagen type 3
# chevrolet impala
# mercury monarch
# mercury capri v6
# dodge colt
# buick opel isuzu deluxe
# buick century special
# toyota corolla 1600 (sw)
# dodge coronet custom
# ford galaxie 500
# toyota corolla 1200
# amc ambassador sst
# toyota corona liftback
# mazda rx-7 gs
# fiat x1.9
# chevy c20
# dodge coronet brougham
# chevrolet cavalier 2-door
# toyota cressida
# toyota starlet
# vokswagen rabbit
# plymouth cricket
# ford granada ghia
# ford mustang
# plymouth horizon miser
# ford gran torino
# oldsmobile cutlass ciera (diesel)
# amc pacer
# toyota corona mark ii
# mercury cougar brougham
# pontiac phoenix lj
# plymouth volare
# mazda glc 4
# audi 100 ls
# volkswagen jetta
# plymouth fury iii
# hi 1200d
# dodge aspen 6
# pontiac sunbird coupe
# plymouth volare custom
# pontiac j2000 se hatchback
# mazda glc deluxe
# vw rabbit custom
# buick skyhawk
# chrysler lebaron salon
# fiat 128
# mazda glc custom l
# subaru dl
# amc matador
# pontiac catalina brougham
# chevrolet monte carlo
# datsun 200-sx
# dodge colt hardtop
# dodge aspen se
# capri ii
# oldsmobile omega brougham
# dodge colt m/m
# mercury zephyr 6
# amc matador (sw)
# ford mustang gl
# chevrolet monte carlo landau
# chrysler new yorker brougham
# ford fiesta
# fiat 131
# ford country squire (sw)
# toyota corolla liftback
# datsun 210 mpg
# toyouta corona mark ii (sw)
# plymouth satellite custom
# mercury marquis brougham
# dodge charger 2.2
# vw dasher (diesel)
# renault 5 gtl
# peugeot 505s turbo diesel
# honda civic 1300
# datsun 810
# volkswagen rabbit l
# peugeot 304
# chevrolet cavalier wagon
# volkswagen 1131 deluxe sedan
# dodge aries wagon (sw)
# oldsmobile omega
# fiat 124 sport coupe
# dodge aries se
# opel 1900
# buick century 350
# plymouth satellite sebring
# renault 18i
# chevrolet monza 2+2
# vw rabbit c (diesel)
# datsun 210
# plymouth fury gran sedan
# volkswagen rabbit
# amc concord dl 6
# mazda rx2 coupe
# plymouth satellite
# chrysler newport royal
# plymouth satellite custom (sw)
# bmw 2002
# pontiac grand prix lj
# peugeot 504 (sw)
# ford fairmont (auto)
# datsun 310 gx
# oldsmobile vista cruiser
# datsun b210 gx
# pontiac ventura sj
# amc ambassador dpl
# dodge magnum xe
# saab 99gle
# chevrolet malibu
# audi 5000
# plymouth champ
# mercedes-benz 280s
# chevrolet cavalier
# volkswagen model 111
# datsun 510 (sw)
# mercury monarch ghia
# honda civic cvcc
# buick century
# toyota corolla tercel
# plymouth custom suburb
# bmw 320i
# renault 12tl
# datsun 200sx
# dodge st. regis
# dodge d200
# volkswagen scirocco
# chevrolet nova custom
# honda prelude
# vw pickup
# volkswagen rabbit custom
# plymouth valiant custom
# volkswagen rabbit custom diesel
# datsun 1200
# volkswagen 411 (sw)
# mercury capri 2000
# ford thunderbird
# plymouth 'cuda 340
# dodge monaco (sw)
# volvo 245
# mercury grand marquis
# ford torino 500
# toyota celica gt liftback
# datsun 310
# plymouth grand fury
# datsun 610
# chevrolet woody
# datsun 510
# ford futura
# plymouth horizon tc3
# dodge d100
# amc concord dl
# toyota corona hardtop
# vw rabbit
# volvo 144ea
# mazda glc custom
# buick lesabre custom
# plymouth fury
# chevy c10
# buick electra 225 custom
# nissan stanza xe

# %%
def process_string(value):
    map_dict = {
    'maxda': 'mazda', 
    "toyouta":  "toyota",
    "vokswagen":  "vw",
    "volkswagen": "vw",
    }
    result = value.lower().strip().split(" ")
    name = result[0]
    if name in map_dict.keys():
        name map_dict[name]
    return name
# Out:
#   Cell In[61], line 11
#     name map_dict[name]
#          ^
# SyntaxError: invalid syntax

# %%
process_string("vw taigun")
# Out:
# 'vw'

# %%
process_string("   FoRD  Eco SPORTS")
# Out:
# 'ford'

# %%
#df["company"] = df["name"].str.split(" ", expand=True)[0]

# %%
df["company"] = df["name"].apply(process_string)

# %%
df["company"].nunique()
# Out:
# 34

# %% [markdown]
#     'maxda' -> 'mazda'
#
#     "toyouta" -> "toyota"
#
#     "vokswagen" -> "vw"
#
#     "volkswagen" -> "vw"

# %%
map_dict = {
    'maxda': 'mazda', 
    "toyouta":  "toyota",
    "vokswagen":  "vw",
    "volkswagen": "vw",
    
}

# %%
df["origin"].map?

# %%
df["origin"].map
# Out:
# <bound method Series.map of 178    europe
# 299    europe
# 360    europe
# 313       usa
# 52     europe
#         ...
# 213       usa
# 95        usa
# 32        usa
# 380     japan
# 131     japan
# Name: origin, Length: 358, dtype: object>

# %%
df["company"].map(map_dict, )
# Out:
# 178    NaN
# 299    NaN
# 360    NaN
# 313    NaN
# 52     NaN
#       ...
# 213    NaN
# 95     NaN
# 32     NaN
# 380    NaN
# 131    NaN
# Name: company, Length: 358, dtype: object

# %%
df["origin"].unique()
# Out:
# array(['europe', 'usa', 'japan'], dtype=object)

# %%
m = {"europe": 1, "usa": 2, "japan": 3}
# map_dict = {"bad value": "good value", "good value": "good value"}

# %%
df["origin"].map(m)
# Out:
# 178    1
# 299    1
# 360    1
# 313    2
# 52     1
#       ..
# 213    2
# 95     2
# 32     2
# 380    3
# 131    3
# Name: origin, Length: 358, dtype: int64

# %%
df["origin"]
# Out:
# 178    europe
# 299    europe
# 360    europe
# 313       usa
# 52     europe
#         ...
# 213       usa
# 95        usa
# 32        usa
# 380     japan
# 131     japan
# Name: origin, Length: 358, dtype: object

# %%
names = sorted(df["company"].unique())

# %%
print(*names, sep="\t")
# Out:
# amc	audi	bmw	buick	capri	chevrolet	chevy	chrysler	datsun	dodge	fiat	ford	hi	honda	maxda	mazda	mercedes-benz	mercury	nissan	oldsmobile	opel	peugeot	plymouth	pontiac	renault	saab	subaru	toyota	toyouta	triumph	vokswagen	volkswagen	volvo	vw

# %% [markdown]
#     df[df[col]=="bad value"][col] = "good value"

# %%
for item in names.copy():
    if item in ['maxda' , "toyouta", "vokswagen", "volkswagen"]:
        names.remove(item)

# %%
map_dict.update(dict(zip(names, names)))

# %%
map_dict
# Out:
# {'maxda': 'mazda',
#  'toyouta': 'toyota',
#  'vokswagen': 'vw',
#  'volkswagen': 'vw',
#  'amc': 'amc',
#  'audi': 'audi',
#  'bmw': 'bmw',
#  'buick': 'buick',
#  'capri': 'capri',
#  'chevrolet': 'chevrolet',
#  'chevy': 'chevy',
#  'chrysler': 'chrysler',
#  'datsun': 'datsun',
#  'dodge': 'dodge',
#  'fiat': 'fiat',
#  'ford': 'ford',
#  'hi': 'hi',
#  'honda': 'honda',
#  'mazda': 'mazda',
#  'mercedes-benz': 'mercedes-benz',
#  'mercury': 'mercury',
#  'nissan': 'nissan',
#  'oldsmobile': 'oldsmobile',
#  'opel': 'opel',
#  'peugeot': 'peugeot',
#  'plymouth': 'plymouth',
#  'pontiac': 'pontiac',
#  'renault': 'renault',
#  'saab': 'saab',
#  'subaru': 'subaru',
#  'toyota': 'toyota',
#  'triumph': 'triumph',
#  'volvo': 'volvo',
#  'vw': 'vw'}

# %%
df["company"] = df["company"].map(map_dict)

# %%
df["company"].nunique()
# Out:
# 30

# %%
print(*sorted(df["company"].unique()), sep="\n")
# Out:
# amc
# audi
# bmw
# buick
# capri
# chevrolet
# chevy
# chrysler
# datsun
# dodge
# fiat
# ford
# hi
# honda
# mazda
# mercedes-benz
# mercury
# nissan
# oldsmobile
# opel
# peugeot
# plymouth
# pontiac
# renault
# saab
# subaru
# toyota
# triumph
# volvo
# vw

# %%
df.groupby("company")["mpg"].describe()\
.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_30021_row0_col0, #T_30021_row22_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_30021_row0_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_30021_row0_col2, #T_30021_row16_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_30021_row0_col3, #T_30021_row6_col5, #T_30021_row7_col3, #T_30021_row7_col4, #T_30021_row11_col3, #T_30021_row21_col3, #T_30021_row22_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_30021_row0_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_30021_row0_col5, #T_30021_row6_col1, #T_30021_row11_col5, #T_30021_row14_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_30021_row0_col6, #T_30021_row3_col5, #T_30021_row22_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_30021_row0_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_30021_row1_col0, #T_30021_row7_col0, #T_30021_row23_col0, #T_30021_row28_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_30021_row1_col1, #T_30021_row6_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_30021_row1_col2, #T_30021_row19_col6, #T_30021_row24_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_30021_row1_col3, #T_30021_row20_col4, #T_30021_row22_col1, #T_30021_row28_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_30021_row1_col4, #T_30021_row7_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_30021_row1_col5, #T_30021_row20_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_30021_row1_col6, #T_30021_row2_col4, #T_30021_row5_col2, #T_30021_row11_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_30021_row1_col7 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_30021_row2_col0, #T_30021_row15_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_30021_row2_col1, #T_30021_row2_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_30021_row2_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_30021_row2_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_30021_row2_col6, #T_30021_row24_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_30021_row2_col7, #T_30021_row7_col7, #T_30021_row19_col7, #T_30021_row29_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_30021_row3_col0, #T_30021_row22_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_30021_row3_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_30021_row3_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_30021_row3_col3, #T_30021_row18_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_30021_row3_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_30021_row3_col6, #T_30021_row21_col1, #T_30021_row28_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_30021_row3_col7, #T_30021_row10_col3, #T_30021_row13_col3, #T_30021_row15_col7, #T_30021_row19_col3, #T_30021_row20_col7, #T_30021_row26_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_30021_row4_col0, #T_30021_row12_col0, #T_30021_row12_col1, #T_30021_row12_col3, #T_30021_row12_col4, #T_30021_row12_col5, #T_30021_row12_col6, #T_30021_row12_col7, #T_30021_row17_col0, #T_30021_row19_col2, #T_30021_row27_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_30021_row4_col1, #T_30021_row4_col3, #T_30021_row4_col4, #T_30021_row4_col5, #T_30021_row15_col6, #T_30021_row19_col1, #T_30021_row19_col5 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_30021_row4_col2, #T_30021_row12_col2, #T_30021_row17_col2, #T_30021_row27_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_30021_row4_col6, #T_30021_row20_col1, #T_30021_row24_col6 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_30021_row4_col7, #T_30021_row5_col1, #T_30021_row24_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_30021_row5_col0, #T_30021_row8_col6 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_30021_row5_col3, #T_30021_row9_col3, #T_30021_row16_col3, #T_30021_row18_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_30021_row5_col4, #T_30021_row9_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_30021_row5_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_30021_row5_col6 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_30021_row5_col7, #T_30021_row8_col4, #T_30021_row10_col4, #T_30021_row23_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_30021_row6_col0, #T_30021_row19_col0, #T_30021_row25_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_30021_row6_col2, #T_30021_row11_col0, #T_30021_row14_col7, #T_30021_row17_col1, #T_30021_row17_col3, #T_30021_row17_col4, #T_30021_row17_col5, #T_30021_row29_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_30021_row6_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_30021_row6_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_30021_row6_col6, #T_30021_row28_col6 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_30021_row7_col1, #T_30021_row7_col5, #T_30021_row7_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_30021_row8_col0, #T_30021_row14_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_30021_row8_col1 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_30021_row8_col2, #T_30021_row24_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_30021_row8_col3, #T_30021_row9_col1, #T_30021_row22_col6, #T_30021_row29_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_30021_row8_col5 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_30021_row8_col7, #T_30021_row13_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_30021_row9_col0, #T_30021_row20_col6 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_30021_row9_col2, #T_30021_row23_col3, #T_30021_row25_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_30021_row9_col5, #T_30021_row20_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_30021_row9_col6 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_30021_row9_col7, #T_30021_row16_col7, #T_30021_row17_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_30021_row10_col0, #T_30021_row18_col0, #T_30021_row20_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_30021_row10_col1, #T_30021_row10_col7, #T_30021_row21_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_30021_row10_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_30021_row10_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_30021_row10_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_30021_row11_col1, #T_30021_row16_col5, #T_30021_row16_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_30021_row11_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_30021_row11_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_30021_row11_col7 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_30021_row13_col0, #T_30021_row14_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_30021_row13_col1 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_30021_row13_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_30021_row13_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_30021_row13_col6, #T_30021_row23_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_30021_row13_col7 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_30021_row14_col1, #T_30021_row25_col5 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_30021_row14_col2, #T_30021_row26_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_30021_row14_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_30021_row14_col6 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_30021_row15_col1, #T_30021_row15_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_30021_row15_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_30021_row15_col3, #T_30021_row25_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_30021_row15_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_30021_row16_col0 {
#   background-color: #8db0fe;
#   color: #00000

# %%
sns.scatterplot(x="horsepower", y="mpg", hue="company", data=df,
               palette="coolwarm")
plt.show()

# %% [markdown]
#
#     Encoding -> Cat to numerical
#
#     Scaling
#
#     Missing Values
#
#     Custom Transformers
#
#     Data Pipeline
